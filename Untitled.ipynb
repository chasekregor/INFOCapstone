# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
conn = sqlite3.connect(r"movielense20million.db")

# %%
model = pd.read_sql_query("SELECT movieId, userId, tagId, relevance, rating FROM ratings INNER JOIN genomescores ON ratings.movie2Id = genomescores.movieId LIMIT 25000;", conn)

# %%
model
# Out:
#        movieId  userId  tagId  relevance  rating
# 0            2       1      1    0.03975     3.5
# 1            2       1      2    0.04375     3.5
# 2            2       1      3    0.03775     3.5
# 3            2       1      4    0.04800     3.5
# 4            2       1      5    0.11025     3.5
# 5            2       1      6    0.07250     3.5
# 6            2       1      7    0.04775     3.5
# 7            2       1      8    0.10975     3.5
# 8            2       1      9    0.09925     3.5
# 9            2       1     10    0.02050     3.5
# 10           2       1     11    0.06775     3.5
# 11           2       1     12    0.08900     3.5
# 12           2       1     13    0.22575     3.5
# 13           2       1     14    0.00625     3.5
# 14           2       1     15    0.00300     3.5
# 15           2       1     16    0.03475     3.5
# 16           2       1     17    0.00950     3.5
# 17           2       1     18    0.18975     3.5
# ...

# %%
model.userId.value_counts()
# Out:
# 1    25000
# Name: userId, dtype: int64
